# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
# Define the CNN model
model = models.Sequential()

# Convolutional layers
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(256, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))


# Additional Convolutional layers
model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(layers.GlobalAveragePooling2D())

# Fully connected layers
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(7, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
     rotation_range=20,
     width_shift_range=0.2,
     height_shift_range=0.2,
     shear_range=0.2,
     zoom_range=0.2,
     horizontal_flip=True,
     rescale = 1./255
)
test_datagen = ImageDataGenerator(rescale=1./255)

# Replace 'path/to/dataset' with the path to your dataset
train_generator = train_datagen.flow_from_directory(
    'C:/Users/sahad/Documents/Python/MobileNet/archive/images/train/',
    target_size=(48, 48),
    color_mode='grayscale',
    batch_size=32,
    class_mode='sparse')

validation_generator = test_datagen.flow_from_directory(
    'C:/Users/sahad/Documents/Python/MobileNet/archive/images/validation/',
    target_size=(48, 48),
    color_mode='grayscale',
    batch_size=32,
    class_mode='sparse')


train_generator.class_indices
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

mc = ModelCheckpoint(filepath="model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

es = EarlyStopping(monitor = "val_accuracy", patience = 10)

stop = [mc, es]

# %%
# Train the model
history = model.fit(train_generator, epochs=40, validation_data=validation_generator, callbacks = stop)
# Out:
# Epoch 1/40
# 901/901 [==============================] - ETA: 0s - loss: 1.8165 - accuracy: 0.2490
# Epoch 1: val_accuracy improved from -inf to 0.25800, saving model to model.h5
# 901/901 [==============================] - 83s 91ms/step - loss: 1.8165 - accuracy: 0.2490 - val_loss: 1.7939 - val_accuracy: 0.2580
# Epoch 2/40
# 901/901 [==============================] - ETA: 0s - loss: 1.7900 - accuracy: 0.2529
# Epoch 2: val_accuracy improved from 0.25800 to 0.28687, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.7900 - accuracy: 0.2529 - val_loss: 1.7337 - val_accuracy: 0.2869
# Epoch 3/40
# 901/901 [==============================] - ETA: 0s - loss: 1.7422 - accuracy: 0.2797
# Epoch 3: val_accuracy improved from 0.28687 to 0.31857, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.7422 - accuracy: 0.2797 - val_loss: 1.6663 - val_accuracy: 0.3186
# Epoch 4/40
# 901/901 [==============================] - ETA: 0s - loss: 1.6919 - accuracy: 0.3072
# Epoch 4: val_accuracy improved from 0.31857 to 0.38155, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.6919 - accuracy: 0.3072 - val_loss: 1.5734 - val_accuracy: 0.3815
# Epoch 5/40
# 901/901 [==============================] - ETA: 0s - loss: 1.6179 - accuracy: 0.3550
# Epoch 5: val_accuracy improved from 0.38155 to 0.44084, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.6179 - accuracy: 0.3550 - val_loss: 1.4419 - val_accuracy: 0.4408
# Epoch 6/40
# 901/901 [==============================] - ETA: 0s - loss: 1.5509 - accuracy: 0.3923
# Epoch 6: val_accuracy improved from 0.44084 to 0.46802, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.5509 - accuracy: 0.3923 - val_loss: 1.4039 - val_accuracy: 0.4680
# Epoch 7/40
# 901/901 [==============================] - ETA: 0s - loss: 1.5052 - accuracy: 0.4142
# Epoch 7: val_accuracy improved from 0.46802 to 0.48924, saving model to model.h5
# 901/901 [==============================] - 81s 90ms/step - loss: 1.5052 - accuracy: 0.4142 - val_loss: 1.3330 - val_accuracy: 0.4892
# Epoch 8/40
# 901/901 [==============================] - ETA: 0s - loss: 1.4723 - accuracy: 0.4291
# Epoch 8: val_accuracy improved from 0.48924 to 0.49123, saving model to model.h5
# 901/901 [==============================] - 82s 90ms/step - loss: 1.4723 - accuracy: 0.4291 - val_loss: 1.3125 - val_accuracy: 0.4912
# Epoch 9/40
# 901/901 [==============================] - ETA: 0s - loss: 1.4450 - accuracy: 0.4377
# Epoch 9: val_accuracy improved from 0.49123 to 0.50835, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.4450 - accuracy: 0.4377 - val_loss: 1.3109 - val_accuracy: 0.5083
# Epoch 10/40
# 901/901 [==============================] - ETA: 0s - loss: 1.4267 - accuracy: 0.4501
# Epoch 10: val_accuracy improved from 0.50835 to 0.51033, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.4267 - accuracy: 0.4501 - val_loss: 1.2847 - val_accuracy: 0.5103
# Epoch 11/40
# 901/901 [==============================] - ETA: 0s - loss: 1.4141 - accuracy: 0.4562
# Epoch 11: val_accuracy did not improve from 0.51033
# 901/901 [==============================] - 83s 92ms/step - loss: 1.4141 - accuracy: 0.4562 - val_loss: 1.2773 - val_accuracy: 0.5081
# Epoch 12/40
# 901/901 [==============================] - ETA: 0s - loss: 1.3977 - accuracy: 0.4653
# Epoch 12: val_accuracy improved from 0.51033 to 0.51826, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.3977 - accuracy: 0.4653 - val_loss: 1.2519 - val_accuracy: 0.5183
# Epoch 13/40
# 901/901 [==============================] - ETA: 0s - loss: 1.3850 - accuracy: 0.4678
# Epoch 13: val_accuracy improved from 0.51826 to 0.52434, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.3850 - accuracy: 0.4678 - val_loss: 1.2500 - val_accuracy: 0.5243
# Epoch 14/40
# 901/901 [==============================] - ETA: 0s - loss: 1.3714 - accuracy: 0.4734
# Epoch 14: val_accuracy improved from 0.52434 to 0.53213, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.3714 - accuracy: 0.4734 - val_loss: 1.2153 - val_accuracy: 0.5321
# Epoch 15/40
# 901/901 [==============================] - ETA: 0s - loss: 1.3657 - accuracy: 0.4746
# Epoch 15: val_accuracy did not improve from 0.53213
# 901/901 [==============================] - 82s 91ms/step - loss: 1.3657 - accuracy: 0.4746 - val_loss: 1.2636 - val_accuracy: 0.5194
# Epoch 16/40
# 901/901 [==============================] - ETA: 0s - loss: 1.3547 - accuracy: 0.4830
# Epoch 16: val_accuracy did not improve from 0.53213
# 901/901 [==============================] - 82s 91ms/step - loss: 1.3547 - accuracy: 0.4830 - val_loss: 1.2338 - val_accuracy: 0.5246
# Epoch 17/40
# 901/901 [==============================] - ETA: 0s - loss: 1.3441 - accuracy: 0.4886
# Epoch 17: val_accuracy improved from 0.53213 to 0.53510, saving model to model.h5
# 901/901 [==============================] - 83s 92ms/step - loss: 1.3441 - accuracy: 0.4886 - val_loss: 1.2068 - val_accuracy: 0.5351
# Epoch 18/40
# 901/901 [==============================] - ETA: 0s - loss: 1.3380 - accuracy: 0.4904
# Epoch 18: val_accuracy improved from 0.53510 to 0.55137, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.3380 - accuracy: 0.4904 - val_loss: 1.1885 - val_accuracy: 0.5514
# Epoch 19/40
# 901/901 [==============================] - ETA: 0s - loss: 1.3317 - accuracy: 0.4907
# Epoch 19: val_accuracy did not improve from 0.55137
# 901/901 [==============================] - 82s 91ms/step - loss: 1.3317 - accuracy: 0.4907 - val_loss: 1.1912 - val_accuracy: 0.5443
# Epoch 20/40
# 901/901 [==============================] - ETA: 0s - loss: 1.3259 - accuracy: 0.4929
# Epoch 20: val_accuracy did not improve from 0.55137
# 901/901 [==============================] - 82s 92ms/step - loss: 1.3259 - accuracy: 0.4929 - val_loss: 1.2048 - val_accuracy: 0.5459
# Epoch 21/40
# 901/901 [==============================] - ETA: 0s - loss: 1.3233 - accuracy: 0.4969
# Epoch 21: val_accuracy did not improve from 0.55137
# 901/901 [==============================] - 82s 91ms/step - loss: 1.3233 - accuracy: 0.4969 - val_loss: 1.2088 - val_accuracy: 0.5314
# Epoch 22/40
# 901/901 [==============================] - ETA: 0s - loss: 1.3150 - accuracy: 0.4965
# Epoch 22: val_accuracy did not improve from 0.55137
# 901/901 [==============================] - 82s 91ms/step - loss: 1.3150 - accuracy: 0.4965 - val_loss: 1.2284 - val_accuracy: 0.5272
# Epoch 23/40
# 901/901 [==============================] - ETA: 0s - loss: 1.3166 - accuracy: 0.4939
# Epoch 23: val_accuracy did not improve from 0.55137
# 901/901 [==============================] - 82s 92ms/step - loss: 1.3166 - accuracy: 0.4939 - val_loss: 1.1684 - val_accuracy: 0.5491
# Epoch 24/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2945 - accuracy: 0.5053
# Epoch 24: val_accuracy improved from 0.55137 to 0.55661, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.2945 - accuracy: 0.5053 - val_loss: 1.1618 - val_accuracy: 0.5566
# Epoch 25/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2970 - accuracy: 0.5050
# Epoch 25: val_accuracy did not improve from 0.55661
# 901/901 [==============================] - 81s 90ms/step - loss: 1.2970 - accuracy: 0.5050 - val_loss: 1.1829 - val_accuracy: 0.5433
# Epoch 26/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2926 - accuracy: 0.5080
# Epoch 26: val_accuracy did not improve from 0.55661
# 901/901 [==============================] - 81s 90ms/step - loss: 1.2926 - accuracy: 0.5080 - val_loss: 1.1752 - val_accuracy: 0.5518
# Epoch 27/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2959 - accuracy: 0.5083
# Epoch 27: val_accuracy improved from 0.55661 to 0.55817, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.2959 - accuracy: 0.5083 - val_loss: 1.1600 - val_accuracy: 0.5582
# Epoch 28/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2860 - accuracy: 0.5132
# Epoch 28: val_accuracy did not improve from 0.55817
# 901/901 [==============================] - 82s 91ms/step - loss: 1.2860 - accuracy: 0.5132 - val_loss: 1.1640 - val_accuracy: 0.5553
# Epoch 29/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2882 - accuracy: 0.5072
# Epoch 29: val_accuracy did not improve from 0.55817
# 901/901 [==============================] - 85s 94ms/step - loss: 1.2882 - accuracy: 0.5072 - val_loss: 1.1650 - val_accuracy: 0.5536
# Epoch 30/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2811 - accuracy: 0.5102
# Epoch 30: val_accuracy improved from 0.55817 to 0.56708, saving model to model.h5
# 901/901 [==============================] - 84s 94ms/step - loss: 1.2811 - accuracy: 0.5102 - val_loss: 1.1290 - val_accuracy: 0.5671
# Epoch 31/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2814 - accuracy: 0.5101
# Epoch 31: val_accuracy did not improve from 0.56708
# 901/901 [==============================] - 84s 94ms/step - loss: 1.2814 - accuracy: 0.5101 - val_loss: 1.1782 - val_accuracy: 0.5535
# Epoch 32/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2767 - accuracy: 0.5143
# Epoch 32: val_accuracy improved from 0.56708 to 0.56807, saving model to model.h5
# 901/901 [==============================] - 85s 94ms/step - loss: 1.2767 - accuracy: 0.5143 - val_loss: 1.1525 - val_accuracy: 0.5681
# Epoch 33/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2746 - accuracy: 0.5151
# Epoch 33: val_accuracy did not improve from 0.56807
# 901/901 [==============================] - 83s 93ms/step - loss: 1.2746 - accuracy: 0.5151 - val_loss: 1.1827 - val_accuracy: 0.5497
# Epoch 34/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2659 - accuracy: 0.5194
# Epoch 34: val_accuracy did not improve from 0.56807
# 901/901 [==============================] - 82s 91ms/step - loss: 1.2659 - accuracy: 0.5194 - val_loss: 1.1309 - val_accuracy: 0.5664
# Epoch 35/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2654 - accuracy: 0.5197
# Epoch 35: val_accuracy did not improve from 0.56807
# 901/901 [==============================] - 82s 91ms/step - loss: 1.2654 - accuracy: 0.5197 - val_loss: 1.1428 - val_accuracy: 0.5668
# Epoch 36/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2575 - accuracy: 0.5240
# Epoch 36: val_accuracy improved from 0.56807 to 0.58123, saving model to model.h5
# 901/901 [==============================] - 82s 91ms/step - loss: 1.2575 - accuracy: 0.5240 - val_loss: 1.1092 - val_accuracy: 0.5812
# Epoch 37/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2577 - accuracy: 0.5243
# Epoch 37: val_accuracy did not improve from 0.58123
# 901/901 [==============================] - 82s 91ms/step - loss: 1.2577 - accuracy: 0.5243 - val_loss: 1.1210 - val_accuracy: 0.5730
# Epoch 38/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2569 - accuracy: 0.5222
# Epoch 38: val_accuracy did not improve from 0.58123
# 901/901 [==============================] - 83s 92ms/step - loss: 1.2569 - accuracy: 0.5222 - val_loss: 1.1166 - val_accuracy: 0.5777
# Epoch 39/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2558 - accuracy: 0.5210
# Epoch 39: val_accuracy did not improve from 0.58123
# 901/901 [==============================] - 83s 92ms/step - loss: 1.2558 - accuracy: 0.5210 - val_loss: 1.1355 - val_accuracy: 0.5590
# Epoch 40/40
# 901/901 [==============================] - ETA: 0s - loss: 1.2513 - accuracy: 0.5248
# Epoch 40: val_accuracy did not improve from 0.58123
# 901/901 [==============================] - 83s 92ms/step - loss: 1.2513 - accuracy: 0.5248 - val_loss: 1.1346 - val_accuracy: 0.5705

# %%
# Loading the best fit model
from keras.models import load_model
model = load_model("C:/Users/sahad/Documents/Python/MobileNet/Iteration/CNN/Modification_2/model.h5")

# %%
plt.figure(figsize=(12, 12))

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
op = dict(zip( train_generator.class_indices.values(), train_generator.class_indices.keys()))

# %%
# Load and preprocess an image for prediction
img_path = 'C:/Users/sahad/Desktop/Test/Surprised/6dfb5660c821203ebfc479951993a0a3.jpg'  # Replace with the path to your test image
original_img = image.load_img(img_path)

img = image.load_img(img_path, target_size=(48, 48), color_mode='grayscale')
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0  # Normalize the pixel values to be between 0 and 1


# Make a prediction
predictions = model.predict(img_array)

# Get the predicted class label
predicted_class = np.argmax(predictions)

# Display the image with the predicted class label

plt.title(f'{op[predicted_class]}')
plt.imshow(original_img)
# Out:
# 1/1 [==============================] - 0s 19ms/step
